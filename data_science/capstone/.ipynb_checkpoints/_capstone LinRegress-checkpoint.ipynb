# %% [markdown]
# ## Capstone Project Priscilla (0206021810012)
# ### Medical Cost, Regression
# source: https://www.kaggle.com/mirichoi0218/insurance

# %% [markdown]
# **import semua yang diperlukan**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tools.eval_measures import rmse
import statsmodels.formula.api as smf
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **masukkan csv ke dalam dataframe, lalu cetak info mengenai dataframe**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pvannyamelia/dsc_kuliah/main/data_science/assets_dsc/insurance.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# *tidak ada missing values pada semua kolom, DataFrame berukuran 1338 rows dengan 6 kolom fitur dan 1 kolom target*

# %% [markdown]
# **cetak 10 data pertama untuk melihat gambaran data**

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %% [markdown]
# Berdasarkan jenis data:
# * nominal: gender, smoker, region
# * ordinal: -
# * interval: bmi
# * ratio: children, age, charges

# %% [markdown]
# **karena ada data yang berupa string, gunakan LabelEncoder untuk mengubah data string menjadi data numeric**

# %%
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df.head(10)
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520
# 5   31    0  25.740         0       0       2   3756.62160
# 6   46    0  33.440         1       0       2   8240.58960
# 7   37    0  27.740         3       0       1   7281.50560
# 8   37    1  29.830         2       0       0   6406.41070
# 9   60    0  25.840         0       0       1  28923.13692

# %% [markdown]
# Data dikonversi menjadi:
# * kolom 'sex' : 0 => female, 1 => male
# * kolom 'smoker' : 0 => no, 1 => yes
# * kolom 'region; : 0 => northeast, 1=> northwest, 2 => southeast, 3 => southwest

# %% [markdown]
# **Hapus yang duplicate**

# %%
dupl = list(df[df.duplicated()==True].index)
print(dupl)
print("Shape Before: ", df.shape)
df.drop(df.index[dupl], inplace=True)
print("Shape After: ", df.shape)
# Out:
# [581]
# Shape Before:  (1338, 7)
# Shape After:  (1337, 7)

# %% [markdown]
# Hanya terdapat 1 row yang duplicated, yaitu indeks ke 581

# %% [markdown]
# **Gunakan .describe() untuk melihat statistik deskriptif tiap kolom**

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1337.000000  1337.000000  1337.000000  1337.000000  1337.000000
# mean     39.222139     0.504862    30.663452     1.095737     0.204936
# std      14.044333     0.500163     6.100468     1.205571     0.403806
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.290000     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.700000     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1337.000000   1337.000000
# mean      1.516081  13279.121487
# std       1.105208  12110.359656
# min       0.000000   1121.873900
# 25%       1.000000   4746.344000
# 50%       2.000000   9386.161300
# 75%       2.000000  16657.717450
# max       3.000000  63770.428010

# %% [markdown]
# dari statistik deskriptif tiap kolom, dapat diamati bahwa mean dan median kolom age, bmi, children tidak terlalu jauh berbeda
#
#
# namun, mean dan median kolom charges terlampau jauh berbeda --> kemungkinan ada outlier
#
#
# meskipun mean dan median bmi tidak jauh berbeda, namun Q3 kolom bmi jika dibandingkan dengan max, jaraknya cukup jauh

# %% [markdown]
# **berdasarkan analisa tabel statistik deskriptif, periksa apakah ada outlier, menggunakan visualisasi data boxplot pada kolom-kolom yang dicurigai**

# %%
sns.boxplot(data=df['bmi'])
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
sns.boxplot(data=df['charges'])
plt.ylabel('charges')
# Out:
# Text(0, 0.5, 'charges')

# %% [markdown]
# *Berdasarkan visualisasi, terdapat outlier pada kolom bmi dan charges*
#
# **Cari outlier dengan z-score**

# %% [markdown]
# *baris dengan nilai mutlak z > 3 adalah outlier*

# %%
df['z_bmi'] = np.abs(stats.zscore(df['bmi']))
outlBmi = list(np.where(np.abs(df['z_bmi']) > 3)[0])
print("BMI Outliers: ", outlBmi)
print("Total BMI outliers: ", len(outlBmi), "\n")

df['z_charges'] = np.abs(stats.zscore(df['charges']))
outlCharges = list(np.where(np.abs(df['z_charges']) > 3)[0])
print("Charges Outliers: ", outlCharges)
print("Total Charges outliers: ", len(outlCharges))

outl = list(set(outlBmi + outlCharges))
# Out:
# BMI Outliers:  [116, 846, 1046, 1316]
# Total BMI outliers:  4
#
# Charges Outliers:  [34, 543, 577, 818, 1145, 1229, 1299]
# Total Charges outliers:  7

# %%
df.iloc[outl, :]
# Out:
#       age  sex     bmi  children  smoker  region      charges     z_bmi  \
# 577    31    0  38.095         1       1       0  58571.07448  1.218649
# 34     28    1  36.400         1       1       3  51194.55914  0.940697
# 1317   18    1  53.130         0       0       2   1163.46270  3.684136
# 1230   52    1  34.485         3       1       1  60021.39897  0.626670
# 847    23    1  50.380         1       0       2   2438.05520  3.233182
# 819    33    0  35.530         0       1       1  55135.40209  0.798032
# 1300   45    1  30.360         0       1       2  62592.87309  0.049761
# 116    58    1  49.060         0       0       2  11381.32540  3.016724
# 1047   22    1  52.580         1       1       2  44501.39820  3.593945
# 1146   60    1  32.800         0       1       3  52590.82939  0.350358
# 543    54    0  47.410         0       1       2  63770.42801  2.746152
#
#       z_charges
# 577    3.741334
# 34     3.131998
# 1317   1.000812
# 1230   3.861138
# ...

# %% [markdown]
# **Drop rows dengan index outlier**

# %%
print(df.shape)
df.drop(df.index[list(outl)], inplace=True)
print(df.shape)
# Out:
# (1337, 9)
# (1326, 9)

# %% [markdown]
# Dari semula 1338 baris, menjadi 1326 baris setelah dibersihkan

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1326.000000  1326.000000  1326.000000  1326.000000  1326.000000
# mean     39.227753     0.503017    30.570743     1.099548     0.200603
# std      14.037019     0.500180     5.992764     1.207167     0.400603
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.220000     0.000000     0.000000
# 50%      39.000000     1.000000    30.300000     1.000000     0.000000
# 75%      51.000000     1.000000    34.560000     2.000000     0.000000
# max      64.000000     1.000000    48.070000     5.000000     1.000000
#
#             region       charges        z_bmi    z_charges
# count  1326.000000   1326.000000  1326.000000  1326.000000
# mean      1.513575  13039.837572     0.795150     0.734449
# std       1.106842  11677.031551     0.577247     0.625285
# min       0.000000   1121.873900     0.003534     0.004153
# ...

# %%
sns.boxplot(data=df['bmi'])
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %% [markdown]
# Outlier pada kolom BMI tidak ada yang |z-score| > 3

# %%
sns.boxplot(data=df['charges'])
plt.ylabel('charges')
# Out:
# Text(0, 0.5, 'charges')

# %% [markdown]
# Outlier pada kolom Charges tidak ada yang |z-score| > 3

# %% [markdown]
# **Cari korelasi antar variabel pada tabel**

# %%
df = df.drop(columns=['z_bmi', 'z_charges'])
corr = df.corr()
sns.heatmap(corr, vmin=-1, vmax=1, cmap = 'coolwarm', annot=True, fmt='.2f', linewidths=0.1)
plt.title("Correlation Between Variables", pad=20)
# Out:
# Text(0.5, 1.0, 'Correlation Between Variables')

# %% [markdown]
# Dari heatmap dapat dilihat bahwa:
#
# 1. dataset yang digunakan sudah cukup bagus (tidak ada keterkaitan yang signifikan antar variabel independen)
#
# 2. jenis kelamin, jumlah anak, dan tempat tinggal tidak signifikan berpengaruh terhadap charges (korelasi terhadap kolom charges < 0.1)
#
# oleh karena itu, variabel independen yang akan digunakan pada proyek ini adalah age, bmi, dan smoker

# %% [markdown]
# **Skewness: pastikan distribusi data seimbang agar tidak menimbulkan bias**

# %% [markdown]
# **Bagi dataset sesuai kolom yang digunakan saja**

# %%
df1 = df[['age', 'bmi', 'smoker', 'charges']]
df2 = df[['sex', 'children', 'region', 'charges']]

# %% [markdown]
# **Cek distribusi data**

# %%
df1.skew()
# Out:
# age        0.054134
# bmi        0.203657
# smoker     1.496989
# charges    1.452917
# dtype: float64

# %% [markdown]
# Source: https://towardsdatascience.com/skewness-kurtosis-simplified-1338e094fc85
#
# * low skewness: [-0.5, 0.5]
#
# * moderate skewness: [-1, -0.5) U (0.5, 1]
#
# * high skewness: <-1, >1
#
# Berdasarkan sumber di atas, diduga distribusi data pada kolom 'smoker' dan 'charges' condong ke salah satu sisi (skewed). Agar lebih pasti, gunakan pairplot untuk melihat distribusi data masing-masing kolom.

# %%
sns.pairplot(df1)

# %% [markdown]
# Berdasarkan nilai skewness dan berdasarkan pairplot yang ditampilkan, dapat disimpulkan bahwa kolom 'smoker' dan 'charges' tidak terdistribusi normal dan memiliki nilai skewness yang tergolong tinggi. Akan tetapi mengingat tipe data kolom smoker merupakan skala nominal, maka tidak perlu dilakukan transformasi pada kolom ini. Meskipun demikian kolom smoker akan tetap dimasukkan ke dalam model regresi linear karena pengaruhnya yang besar terhadap variabel dependen.
#
# Di lain sisi, menurut pairplot, kolom age juga cenderung terkumpul di sebelah kiri, walau nilai skewness menunjukkan angka yang bagus. Oleh karena itu kita perlu mentransformasi kolom 'age' dan 'charges' agar datanya terdistribusi normal. Kita akan menggunakan Log Transformation untuk mentransformasi data karena Log Transformation tidak pernah menghasilkan nilai negatif (data kolom 'age' dan 'charges' tidak boleh negatif).

# %% [markdown]
# **Handle Skewness using Log Transformation**

# %% [markdown]
# Tahapan transformasi data:
# * Transformasi kolom yang diperlukan ('age' dan 'charges') menggunakan logaritma dengan basis 10, lalu simpan ke dalam variabel dataframe baru.
# * Tambahkan ke dalam dataframe baru variabel independen yang lain ('smoker' dan 'bmi')
# * Urutkan kolom dataframe

# %%
dfUsed = np.log10(df1[['age', 'charges']])
dfUsed = dfUsed.join(df1[['smoker', 'bmi']])
dfUsed = dfUsed[['age', 'bmi', 'smoker', 'charges']]

# %% [markdown]
# **Visualisasi korelasi antar variabel**

# %% [markdown]
# Pastikan pengaruh variabel independen terhadap variabel dependen setelah data di transformasi menggunakan heatmap.

# %%
corr = dfUsed.corr()
sns.heatmap(corr, vmin=-1, vmax=1, cmap = 'coolwarm', annot=True, fmt='.2f', linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ternyata, setelah data di transformasi, korelasi antara variabel independen dan variabel dependen masih kuat (korelasi positif). Bahkan korelasi pada kolom age terhadap charges bertambah dari sebelumnya.

# %% [markdown]
# # Building the model
#
# reference: https://medium.com/datadriveninvestor/k-fold-cross-validation-6b8518070833
#
# Tahap preprocessing telah selesai, sebelum memulai untuk membangun data, mari kita cek terlebih dahulu dataframe yang akan digunakan.

# %%
dfUsed.head()
# Out:
#         age     bmi  smoker   charges
# 0  1.278754  27.900       1  4.227499
# 1  1.255273  33.770       0  3.236928
# 2  1.447158  33.000       0  3.648308
# 3  1.518514  22.705       0  4.342116
# 4  1.505150  28.880       0  3.587358

# %% [markdown]
# **pisahkan dataset menjadi variabel dependen (y) dan variabel independen (X)**

# %%
X = dfUsed.iloc[:, :-1].values
y = dfUsed.iloc[:, -1].values

# %% [markdown]
# **Bangun model linear regression**

# %% [markdown]
# Untuk mengukur model regresi linear kita, ada 2 hal yang digunakan:
# 1. R-squared score: untuk mengukur seberapa besar variabel dependen dapat dijelaskan oleh variabel independen
# 2. Root Mean Square Error: tingkat akurasi prediksi model, semakin mendekati 0 semakin akurat
#
# K-Fold Cross validation digunakan untuk meningkatkan generalisasi model dalam belajar, juga untuk menghindari overfitting. Jumlah fold yang digunakan adalah 10 (n_splits=10).

# %%
scores=[] #to store r squared
rmse_list=[] #to store RMSE
lrmodel = LinearRegression()
cv = KFold(n_splits=10, random_state=42, shuffle=True)
for train_index, test_index in cv.split(X):
#     print("Train index: ", train_index, "\n")
#     print("Test index: ", test_index)
    
    X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]
    lrmodel.fit(X_train, y_train)
    y_predict = lrmodel.predict(X_test)
    scores.append(lrmodel.score(X_test, y_test))
    rmse_fold = rmse(y_test, y_predict)
#     print(rmse_fold)
    rmse_list.append(rmse_fold)

lm = smf.ols(formula='charges ~ age + bmi + smoker', data = dfUsed).fit()
comparison = pd.DataFrame({"y_test": y_test, "y_predict": y_predict})
print("Summary: ", lm.summary())
print("R Squared Mean: ", np.mean(scores))
print("RMSE mean: ", np.mean(rmse_list))
# Out:
# Summary:                              OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.747
# Model:                            OLS   Adj. R-squared:                  0.747
# Method:                 Least Squares   F-statistic:                     1302.
# Date:                Sun, 17 Jan 2021   Prob (F-statistic):               0.00
# Time:                        22:24:01   Log-Likelihood:                 263.10
# No. Observations:                1326   AIC:                            -518.2
# Df Residuals:                    1322   BIC:                            -497.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6725      0.056     30.134      0.000       1.564       1.781
# ...

# %% [markdown]
# Dari output di atas:
# 1. nilai R-squared rata-rata tiap iterasi adalah 0.739, berarti variabel dependen dapat dijelaskan oleh variabel independen dengan baik (umumnya nilai R-squared 0.6 sudah dianggap baik).
# 2. berdasarkan nilai rata-rata RMSE tiap iterasi, prediksi model regresi linear ini akurat hingga 80.2%
#
# Di bawah ini merupakan sample perbadingan nilai y_test dan y_predict dari model regresi linear

# %%
comparison.sample(10)
# Out:
#        y_test  y_predict
# 85   3.737037   3.749616
# 14   3.711987   3.738773
# 73   4.047305   3.997728
# 64   3.906776   3.983202
# 57   3.747788   3.790452
# 78   3.630038   3.781092
# 129  4.577833   4.560792
# 113  4.053053   4.003554
# 99   3.233257   3.389600
# 67   4.004585   3.967914

# %% [markdown]
# **Visualisasi model dalam 3D**

# %% [markdown]
# Karena keterbatasan visual (hanya bisa maksimal 3D), visualisasi model regresi linear ini hanya akan menampilkan 2 variabel independen (bmi dan age, karena smoker adalah skala nominal) dan variabel dependen. Oleh karena itu, perlu dibuat model baru khusus visualisasi yang hanya mencakup variabel age, bmi, dan charges.

# %%
X1 = dfUsed.iloc[:, :-2].values
y1 = dfUsed.iloc[:, -1].values
lrmodel1 = LinearRegression()

for train_index, test_index in cv.split(X1):
    X_train1, X_test1, y_train1, y_test1 = X1[train_index], X1[test_index], y1[train_index], y1[test_index]
    fit = lrmodel1.fit(X_train1, y_train1)

# %%
coefs = lrmodel.coef_
intercept = lrmodel.intercept_
x = X[:, 0] #age
y = X[:, 1] #bmi
z = y

fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:, 0], X_train[:, 1], y_train, marker='o', alpha=0.5)
ax.set_xlabel("Age")
ax.set_ylabel("BMI")
ax.set_zlabel("Charges")
ax.set_title("Equation: y = {:.2f} + {:.2f}*Xage + {:.2f}*Xbmi + {:.2f}*Xsmoker".format(intercept, coefs[0], coefs[1], coefs[2]))
xx, yy = np.meshgrid(x, y)
exog1 = pd.DataFrame({'age':xx.ravel(), 'bmi':yy.ravel()})
out=fit.predict(exog1)

ax.plot_surface(xx, yy, out.reshape(xx.shape), alpha=0.1)
ax.view_init(10, 30)
plt.show()

# %% [markdown]
# **coba prediksi dengan data baru**

# %%
# age, bmi, smoker
def prediction(age, bmi, smoker):
    whatif = np.log10(np.array([[age]]))
    whatif = np.append(whatif, [bmi, smoker]) #status smoker, 0: non smoker, 1: smoker
    status = "smoker" if smoker==1 else "non-smoker"
    print("Health insurance cost prediction for age:", age, "y.o., BMI:", bmi,", and", status, np.power(10, lrmodel.predict([whatif])))
    
prediction(age=39, bmi=27.9, smoker=0)
# Out:
# Health insurance cost prediction for age: 39 y.o., BMI: 27.9 , and non-smoker [6864.697656]
