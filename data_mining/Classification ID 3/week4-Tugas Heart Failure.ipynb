# %% [markdown]
# # Import Library

# %%
import numpy
from scipy.stats import entropy
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plotLib
import pandas as pd
import pprint

# %% [markdown]
# # Preparing Dataset

# %% [markdown]
# ## Load Dataset from xls

# %%
df = pd.read_csv("../sources/heart_failure_clinical_records_dataset.csv")
df = df[['anaemia', 'high_blood_pressure', 'sex', 'smoking', 'diabetes', 'DEATH_EVENT']]
print(df.describe())
df['DEATH_EVENT']= df['DEATH_EVENT'].replace([0, 1], ['none', 'heart_failure'])
df['sex']= df['sex'].replace([0, 1], ['Female', 'Male'])
df
# Out:
#           anaemia  high_blood_pressure         sex    smoking    diabetes  \
# count  299.000000           299.000000  299.000000  299.00000  299.000000
# mean     0.431438             0.351171    0.648829    0.32107    0.418060
# std      0.496107             0.478136    0.478136    0.46767    0.494067
# min      0.000000             0.000000    0.000000    0.00000    0.000000
# 25%      0.000000             0.000000    0.000000    0.00000    0.000000
# 50%      0.000000             0.000000    1.000000    0.00000    0.000000
# 75%      1.000000             1.000000    1.000000    1.00000    1.000000
# max      1.000000             1.000000    1.000000    1.00000    1.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000
#      anaemia  high_blood_pressure     sex  smoking  diabetes    DEATH_EVENT
# 0          0                    1    Male        0         0  heart_failure
# 1          0                    0    Male        0         0  heart_failure
# 2          0                    0    Male        1         0  heart_failure
# 3          1                    0    Male        0         0  heart_failure
# 4          1                    0  Female        0         1  heart_failure
# ..       ...                  ...     ...      ...       ...            ...
# 294        0                    1    Male        1         1           none
# 295        0                    0  Female        0         0           none
# 296        0                    0  Female        0         1           none
# 297        0                    0    Male        1         0           none
# 298        0                    0    Male        1         0           none
#
# [299 rows x 6 columns]

# %% [markdown]
# ## Get Input Attributes

# %%
selectedInput = ['high_blood_pressure', 'sex', 'smoking', 'diabetes']
inputAttributes = df[selectedInput]
inputAttributes
# Out:
#      high_blood_pressure     sex  smoking  diabetes
# 0                      1    Male        0         0
# 1                      0    Male        0         0
# 2                      0    Male        1         0
# 3                      0    Male        0         0
# 4                      0  Female        0         1
# ..                   ...     ...      ...       ...
# 294                    1    Male        1         1
# 295                    0  Female        0         0
# 296                    0  Female        0         1
# 297                    0    Male        1         0
# 298                    0    Male        1         0
#
# [299 rows x 4 columns]

# %% [markdown]
# ## Get Input Attributes' values

# %%
# anmValues = inputAttributes.anaemia.unique()
hbpValues = inputAttributes.high_blood_pressure.unique()
sexValues = inputAttributes.sex.unique()
smkValues = inputAttributes.smoking.unique()
dbtValues = inputAttributes.diabetes.unique()

# print(anmValues)
print(hbpValues)
print(sexValues)
print(smkValues)
print(dbtValues)
# Out:
# [1 0]
# ['Male' 'Female']
# [0 1]
# [0 1]

# %% [markdown]
# ## Get target attributes

# %%
selectedTarget = ['DEATH_EVENT']
targetAttribute = df[selectedTarget]
targetAttribute
# Out:
#        DEATH_EVENT
# 0    heart_failure
# 1    heart_failure
# 2    heart_failure
# 3    heart_failure
# 4    heart_failure
# ..             ...
# 294           none
# 295           none
# 296           none
# 297           none
# 298           none
#
# [299 rows x 1 columns]

# %% [markdown]
# ## Get target attributes' values

# %%
targetValues = targetAttribute.DEATH_EVENT.unique()

# %% [markdown]
# ## Count Instances and Target Distribution

# %%
targetDataFrame = df['DEATH_EVENT'].value_counts()
totalInstance = df['DEATH_EVENT'].value_counts().sum()

# %% [markdown]
# # Preparing attributes impurity

# %% [markdown]
# ## Get Anemia and its values

# %%
getAnmYes = df.loc[df["anaemia"] == "1"]
getAnmNo = df.loc[df["anaemia"] == "0"]

# %%
targetAnmYes = getAnmYes.DEATH_EVENT.value_counts()
targetAnmNo = getAnmNo.DEATH_EVENT.value_counts()

# %%
getAnmYesSum = targetAnmYes.sum()
getAnmNoSum = targetAnmNo.sum()

# %% [markdown]
# ## Get High Blood Pressure and its values

# %%
getHBPYes = df.loc[df["high_blood_pressure"] == "1"]
getHBPNo = df.loc[df["high_blood_pressure"] == "0"]

# %%
targetHBPYes = getHBPYes.DEATH_EVENT.value_counts()
targetHBPNo = getHBPNo.DEATH_EVENT.value_counts()

# %%
getHBPYesSum = targetHBPYes.sum()
getHBPNoSum = targetHBPNo.sum()

# %% [markdown]
# ## Get Sex and its values

# %%
getMale = df.loc[df["sex"] == "Male"]
getFemale = df.loc[df["sex"] == "Female"]

# %%
targetMale = getMale.DEATH_EVENT.value_counts()
targetFemale = getFemale.DEATH_EVENT.value_counts()

# %%
getMaleSum = targetMale.sum()
getFemaleSum = targetFemale.sum()

# %% [markdown]
# ## Get Smoking and its values

# %%
getSmkNo = df.loc[df['smoking']=="0"]
getSmkYes = df.loc[df['smoking']=="1"]

# %%
targetSmkNo = getSmkNo.DEATH_EVENT.value_counts()
targetSmkYes = getSmkYes.DEATH_EVENT.value_counts()

# %%
getSmkNoSum = targetSmkNo.sum()
getSmkYesSum = targetSmkYes.sum()

# %% [markdown]
# ## Get Diabetes and its values

# %%
getDbtNo = df.loc[df['diabetes']=="0"]
getDbtYes = df.loc[df['diabetes']=="1"]

# %%
targetDbtNo = getDbtNo.DEATH_EVENT.value_counts()
targetDbtYes = getDbtYes.DEATH_EVENT.value_counts()

# %%
getDbtNoSum = targetDbtNo.sum()
getDbtYesSum = targetDbtYes.sum()

# %% [markdown]
# # Let's Loop it

# %%
targetDataFrame
# Out:
# none             203
# heart_failure     96
# Name: DEATH_EVENT, dtype: int64

# %% [markdown]
# ## Gini Function

# %%
def Gini(p, q):
    result = 1 - ((p**2)+(q**2))
    return result

# %% [markdown]
# ## Calculate DF's base entropy and gini

# %%
p = targetDataFrame[0]/totalInstance
q = targetDataFrame[1]/totalInstance

baseEntropy = entropy([p,q], base=2)
baseGini = Gini(p, q)

print("Base Entropy:", baseEntropy)
print("Base Gini:", baseGini)
# Out:
# Base Entropy: 0.9055415027672631
# Base Gini: 0.43596827775975666

# %% [markdown]
# ## Loop each attribute and loop each value

# %%
for attribute in selectedInput:
    print("Attribute: ", attribute)
    attributeValues = df[attribute].unique()
    #
    sumEntropy = 0
    sumGini = 0
    for value in attributeValues:
        subDataFrame = df.loc[df[attribute]==value]
        sumDataFrame = subDataFrame[selectedTarget].value_counts().sum()
        #
        print("Value: ", value, " , Total: ", sumDataFrame, " of ", totalInstance, " Instances")
        print(subDataFrame[selectedTarget].value_counts().to_frame())
        #
        totalIndex = subDataFrame[selectedTarget].value_counts().count()
        p = subDataFrame[selectedTarget].value_counts()[0]/sumDataFrame
        if(totalIndex == 1):
            q = 0
        else:
            q = subDataFrame[selectedTarget].value_counts()[1]/sumDataFrame
        #
        valueEntropy = (sumDataFrame/totalInstance)*(entropy([p,q], base=2))
        sumEntropy += valueEntropy
# Out:
# Attribute:  high_blood_pressure
# Value:  1  , Total:  105  of  299  Instances
#                 0
# DEATH_EVENT
# none           66
# heart_failure  39
# Value:  0  , Total:  194  of  299  Instances
#                  0
# DEATH_EVENT
# none           137
# heart_failure   57
# Attribute:  sex
# Value:  Male  , Total:  194  of  299  Instances
#                  0
# DEATH_EVENT
# none           132
# heart_failure   62
# Value:  Female  , Total:  105  of  299  Instances
#                 0
# DEATH_EVENT
# none           71
# heart_failure  34
# Attribute:  smoking
# Value:  0  , Total:  203  of  299  Instances
#                  0
# DEATH_EVENT
# none           137
# heart_failure   66
# Value:  1  , Total:  96  of  299  Instances
#                 0
# DEATH_EVENT
# none           66
# heart_failure  30
# Attribute:  diabetes
# Value:  0  , Total:  174  of  299  Instances
#                  0
# DEATH_EVENT
# none           118
# heart_failure   56
# Value:  1  , Total:  125  of  299  Instances
#                 0
# DEATH_EVENT
# none           85
# heart_failure  40

# %% [markdown]
# # Let's recursive it!

# %% [markdown]
# ## Function to calculate Parent's entropy

# %%
def getParentEntropy(df, target):
    targetDataFrame = df[target].value_counts()
    totalInstance = df[target].value_counts().sum()
    #
    p = targetDataFrame[0]/totalInstance
    q = targetDataFrame[1]/totalInstance
    #
    baseEntropy = entropy([p,q], base=2)
    baseGini = Gini(p, q)
    #
    result = baseEntropy
    return result

# %% [markdown]
# ## Function to Calculate Children's entropy

# %%
def getChildEntropy(df, target, attribute):
    totalInstance = df[target].value_counts().sum()
    attributeValues = df[attribute].unique()
    #
    sumEntropy = 0
    sumGini = 0
    for value in attributeValues:
        subDataFrame = df.loc[df[attribute]==value]
        sumDataFrame = subDataFrame[selectedTarget].value_counts().sum()
        #
        valueEntropy = 0
        valueGini = 0
        #
        totalIndex = subDataFrame[selectedTarget].value_counts().count()
        if(totalIndex <1):
            p=0
            q=0
        else:
            p = subDataFrame[selectedTarget].value_counts()[0]/sumDataFrame
            if(totalIndex == 1):
                q = 0
            else:
                q = subDataFrame[selectedTarget].value_counts()[1]/sumDataFrame
            #
            valueEntropy = (sumDataFrame/totalInstance)*(entropy([p,q], base=2))
            valueGini = (sumDataFrame/totalInstance)*(Gini(p,q))
        #
        sumEntropy += valueEntropy
        sumGini += valueGini
    result = sumEntropy
    return abs(result)

# %% [markdown]
# ## Function to find best attribute

# %%
def findBestAttribute(df, target):
    gainList = []
    #
    parentEntropy = getParentEntropy(df, target)
    for attribute in df.keys()[:-1]:
        childEntropy = getChildEntropy(df, target, attribute)
        gain = parentEntropy - childEntropy
        gainList.append(gain)
        
    result = df.keys()[numpy.argmax(gainList)]
    return result

# %% [markdown]
# ## Function to Split Dataset

# %%
def getSubBranch(df, attribute, value):
    return df[df[attribute]==value].reset_index(drop=True)

# %% [markdown]
# ## Function Recursive ID3

# %%
def ID3(df, tree=None):
    selectedTarget = ['DEATH_EVENT']
    bestAttribute = findBestAttribute(df, selectedTarget)
    bestAttValues = df[bestAttribute].unique()
    if tree is None:
        tree = {}
        tree[bestAttribute] = {}
    for value in bestAttValues:
        nextBranch = getSubBranch(df, bestAttribute, value)
        nextBranchValue, nextBranchCounts = numpy.unique(nextBranch[selectedTarget], return_counts=True)
#         print(int(numpy.where(nextBranchCounts==max(nextBranchCounts))[0]))
        if len(nextBranchCounts)==1:
            tree[bestAttribute][value] = nextBranchValue[0]
        else:
            tree[bestAttribute][value] = ID3(nextBranch)
#         else:
#             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#             tree[bestAttribute][value] = nextBranchValue[valueIndex]
            
    result = tree
    return result

# %% [markdown]
# # Let's Run Our ID3

# %%
myTree = ID3(df)
pprint.pprint(myTree)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-9f5a18084c7e> in <module>
# ----> 1 myTree = ID3(df)
#       2 pprint.pprint(myTree)
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
# ...
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#      13             tree[bestAttribute][value] = nextBranchValue[0]
#      14         else:
# ---> 15             tree[bestAttribute][value] = ID3(nextBranch)
#      16 #         else:
#      17 #             valueIndex = numpy.where(nextBranchCounts==max(nextBranchCounts))[0][0]
#
# <ipython-input-29-7d2204b8b0ae> in ID3(df, tree)
#       1 def ID3(df, tree=None):
#       2     selectedTarget = ['DEATH_EVENT']
# ----> 3     bestAttribute = findBestAttribute(df, selectedTarget)
#       4     bestAttValues = df[bestAttribute].unique()
#       5     if tree is None:
#
# <ipython-input-27-af5069acbeee> in findBestAttribute(df, target)
#       4     parentEntropy = getParentEntropy(df, target)
#       5     for attribute in df.keys()[:-1]:
# ----> 6         childEntropy = getChildEntropy(df, target, attribute)
#       7         gain = parentEntropy - childEntropy
#       8         gainList.append(gain)
#
# <ipython-input-26-c639501626ad> in getChildEntropy(df, target, attribute)
#       7     for value in attributeValues:
#       8         subDataFrame = df.loc[df[attribute]==value]
# ----> 9         sumDataFrame = subDataFrame[selectedTarget].value_counts().sum()
#      10         #
#      11         valueEntropy = 0
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in value_counts(self, subset, normalize, sort, ascending)
#    5560
#    5561         if sort:
# -> 5562             counts = counts.sort_values(ascending=ascending)
#    5563         if normalize:
#    5564             counts /= counts.sum()
#
# D:\anaconda3\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3276         if na_position == "last":
#    3277             n = good.sum()
# -> 3278             sorted_index[:n] = idx[good][argsorted]
#    3279             sorted_index[n:] = idx[bad]
#    3280         elif na_position == "first":
#
# KeyboardInterrupt:
