# %%
from googleapiclient.discovery import build
my_api_key = "AIzaSyBoFOJYMOtqg-DDTV8K9_lT7UzQ_dTTvQk"
my_cse_id = "2c2aca72571031d4e"

def google_search(search_term, api_key, cse_id, restrict, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    if(restrict == False):
        print('no restriction')
        res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    else:
        print('restrict')
        res = service.cse().siterestrict().list(dateRestrict='1', cx=cse_id, q=search_term,  **kwargs).execute()
    return res

result = google_search("Book", my_api_key, my_cse_id, False)
print(result)
# Out:
# no restriction
# ...
